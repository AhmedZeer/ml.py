# %%
'''
    We have a couple of assumptions about different classifiers' results
    for the same task. If these assumptions are met, we can conclude
    that using a bunch of classifiers will lead to smaller error.
'''

# %%
from scipy.special import comb
import math

# %%
def ensemble_error( n_classifier, error ):
    k_start = int(math.ceil( n_classifier / 2.0 ))
    probs = [comb( n_classifier, k ) * error ** k * ( 1 - error ) ** ( n_classifier - k ) for k in range( k_start, n_classifier + 1) ]
    return sum(probs)

# %%
ensemble_error( n_classifier=10, error=0.24 )

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
errors = np.linspace( 0, 1.1, 10 )
errors = np.arange( 0.1, 1.1, 0.1 )

# %%
errors

# %%
ensemble_errors = []
for e in errors:
    ensemble_errors.append( ensemble_error( n_classifier=11, error=e) )

# %%
ensemble_errors

# %%
plt.plot( errors, ensemble_errors )
plt.plot( errors, errors )
plt.grid()

# %%
ex = np.array( [ [0.9,0.1], [0.6,0.2], [0.8, 0.4] ] )

# %%
p = np.average( ex, axis = 0, weights = [ 0.2, 0.2, 0.6 ] )

# %%
np.argmax(p)

# %% [markdown]
# ### Majority Classifier.

# %%
from sklearn.base import BaseEstimator
from sklearn.base import ClassifierMixin
from sklearn.preprocessing import LabelEncoder
from sklearn.base import clone
from sklearn.pipeline import _name_estimators
import numpy as np
import operator

# %%
class MajorityVoteClassifier(BaseEstimator, ClassifierMixin):
    def __init__( self, classifiers, vote = "classlabel", weights = None ):
        self.classifiers = classifiers
        self.named_classifiers = {
            k:v for k, v in _name_estimators(classifiers)
        }
        self.vote = vote
        self.weights = weights

    def fit( self, X, y ):
        if self.vote not in ( "classlabel", "probability" ):
            raise ValueError ( f"Must be ( \"classlabel\", \"probability\" ) got{vote} " )
        if self.weights and len(self.weights) != len(classifiers):
            raise ValueError ( f"Number of weights & classifiers must be equal len(weights) : {len(self.weights)}"
                               f"len(classifiers) : {len(self.classifiers)}")
        self.labelenc_ = LabelEncoder()
        self.labelenc_.fit(y)
        self.classes_ = self.labelenc_.classes_
        self.classifiers_ = []
        for cls in self.classifiers:
            fitted_clf = clone(cls).fit(X, self.labelenc_.transform(y) )
            self.classifiers_.append(fitted_clf)
        return self

    def predict( self, X ):
        if self.vote == "probability":
            maj_vote = np.argmax( self.predict_proba(X), axis = 1 )
        else:
            predictions = np.asarray([ clf.predict(X) for clf in self.classifiers_ ]).T
            maj_vote = np.apply_along_axis( lambda x: np.argmax( np.bincount(x, weights = self.weights) )
                                           ,axis = 1 , arr = predictions )
            
            maj_vote = self.labelenc_.inverse_transform(maj_vote)
            return maj_vote

    def predict_proba( self, X ):
        probas = np.asarray( [ clf.predict_proba(X) for clf in self.classifiers_ ] )
        avg_probas = np.average( probas, axis = 0, weights = self.weights )
        return avg_probas

    def get_params( self, deep = True ):
        if not deep:
            return super().get_params( deep=False )
        else:
            out = self.named_classifiers.copy()
            for name, step in self.named_classifiers.items():
                for key, value in step.get_params( deep = True ).items():
                    out[f"{name}__{step}"] = value
            return out

# %%
from sklearn import datasets
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()

# %%
X = iris.data[ 50:, [1,2] ]
y = iris.target[ 50: ]

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.5, random_state = 0 )

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
import numpy as np

# %%
clf1 = LogisticRegression( penalty="l2", solver = "lbfgs", C = 0.001, random_state = 0 )
clf2 = DecisionTreeClassifier( criterion = "entropy", max_depth = 1 ,random_state = 0 )
clf3 = KNeighborsClassifier( n_neighbors = 1, p = 2, metric = "minkowski" )

pipe1 = Pipeline( [ [ 'sc', StandardScaler() ], ['clf', clf1 ] ] )
# pipe2 = Pipeline( [ [ 'sc', StandardScaler() ], ['clf', clf2 ] )
pipe3 = Pipeline( [ [ 'sc', StandardScaler() ], ['clf', clf3 ] ] )

clf_labels = ["LogisticRegression", "DecisionTree", "KNeighbors"]

for clf, label in zip( [pipe1, clf2, pipe3], clf_labels ):
    scores = cross_val_score( estimator = clf, cv = 10, X = X_train, y = y_train, scoring = 'roc_auc' )
    print( f"Mean: {np.mean(scores):.2f}, Std: {np.std(scores):.2f} [{label}]")
# Out:
# Mean: 0.97, Std: 0.07 [LogisticRegression]
# Mean: 0.97, Std: 0.07 [DecisionTree]
# Mean: 0.98, Std: 0.05 [KNeighbors]

# %%
mv_clf = MajorityVoteClassifier( classifiers=[ pipe1, clf2, pipe3 ] )

# %%
clf_labels += ["Majority Classifier"]

# %%
for clf, label in zip( [pipe1, clf2, pipe3, mv_clf], clf_labels ):
    scores = cross_val_score( estimator = clf, cv = 2, X = X_train, y = y_train, scoring = 'roc_auc' )
    print( f"Mean: {np.mean(scores):.2f}, Std: {np.std(scores):.2f} [{label}]")
# Out:
# Mean: 0.96, Std: 0.00 [LogisticRegression]
# Mean: 0.98, Std: 0.02 [DecisionTree]
# Mean: 0.88, Std: 0.04 [KNeighbors]
# Mean: 0.99, Std: 0.00 [Majority Classifier]

# %%
from sklearn.metrics import auc
from sklearn.metrics import roc_curve

# %%
colors = [ "black", "orange", "green", "blue" ]
markers = [ "-", ":", "-.", "--" ]
classifiers = [pipe1, clf2, pipe3, mv_clf]

for c, m, l, clf, in zip( colors, markers, clf_labels, classifiers ):
    y_pred = clf.fit( X_train, y_train ).predict_proba( X_test )[:,1]
    fpr, tpr, threshold = roc_curve( y_true = y_test, y_score = y_pred )
    plt.plot( fpr, tpr, color = c, linestyle = m, label = l ) 

plt.legend( loc="best" )
plt.grid()
plt.tight_layout()
plt.show()

# %%
sc = StandardScaler()

# %%
X_train_std = sc.fit_transform( X_train )

# %%
from itertools import product

# %%
X_min = X_train_std[:, 0].min() - 1
y_min = X_train_std[:, 1].min() - 1

X_max = X_train_std[:, 0].max() + 1
y_max = X_train_std[:, 1].max() + 1

# %%
xx, yy = np.meshgrid( np.arange(X_min, X_max, 0.1), np.arange(y_min, y_max, 0.1) )

# %%
Z = classifiers[3].predict(np.c_[xx.ravel(), yy.ravel()])

# %%
Z
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
Z.shape
# Out:
# (4002,)

# %%
f, axr = plt.subplots( nrows = 2, ncols = 2, sharex = "col", sharey = "row", figsize = (7,5)  )

for clf, index, tt in zip( classifiers, product( [0,1],[0,1] ), label ):
    clf.fit( X_train_std, y_train )
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()]).reshape( xx.shape )
    axr[ index[0], index[1] ].contourf( xx, yy, Z, alpha = 0.3 )
    axr[ index[0], index[1] ].scatter( X_train_std[ y_train == 0, 1], X_train_std[ y_train == 0, 0], color="blue" )
    axr[ index[0], index[1] ].scatter( X_train_std[ y_train == 1, 1], X_train_std[ y_train == 1, 0], color="orange" )

# %%
mv_clf.get_params()
# Out:
# {'pipeline-1': Pipeline(steps=[('sc', StandardScaler()),
#                  ['clf', LogisticRegression(C=0.001, random_state=0)]]),
#  'decisiontreeclassifier': DecisionTreeClassifier(criterion='entropy', max_depth=1, random_state=0),
#  'pipeline-2': Pipeline(steps=[('sc', StandardScaler()),
#                  ['clf', KNeighborsClassifier(n_neighbors=1)]]),
#  "pipeline-1__Pipeline(steps=[('sc', StandardScaler()),\n                ['clf', LogisticRegression(C=0.001, random_state=0)]])": False,
#  "decisiontreeclassifier__DecisionTreeClassifier(criterion='entropy', max_depth=1, random_state=0)": 'best',
#  "pipeline-2__Pipeline(steps=[('sc', StandardScaler()),\n                ['clf', KNeighborsClassifier(n_neighbors=1)]])": 'uniform'}

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'decisiontreeclassifier__max_depth' : [1,2],
    'pipeline-1__clf__C' : [ 0.001, 0.01, 100 ]
}

# %%
gs = GridSearchCV( param_grid = param_grid, cv = 10, scoring="roc_auc", estimator = mv_clf )

# %%
gs.fit( X_train, y_train )
# Out:
# GridSearchCV(cv=10,
#              estimator=MajorityVoteClassifier(classifiers=[Pipeline(steps=[('sc',
#                                                                             StandardScaler()),
#                                                                            ['clf',
#                                                                             LogisticRegression(C=0.001,
#                                                                                                random_state=0)]]),
#                                                            DecisionTreeClassifier(criterion='entropy',
#                                                                                   max_depth=1,
#                                                                                   random_state=0),
#                                                            Pipeline(steps=[('sc',
#                                                                             StandardScaler()),
# ...

# %%
for r, _ in enumerate( gs.cv_results_['mean_test_score'] ):
    fit_time = gs.cv_results_['mean_fit_time'][r]
    mean = gs.cv_results_['mean_test_score'][r]
    print(f"Time To Fit: {fit_time}, Mean Score: {mean}")
# Out:
# Time To Fit: 0.003589916229248047, Mean Score: 1.0
# Time To Fit: 0.0032323360443115234, Mean Score: 1.0
# Time To Fit: 0.003343653678894043, Mean Score: 1.0
# Time To Fit: 0.002881622314453125, Mean Score: 1.0
# Time To Fit: 0.0025766611099243162, Mean Score: 1.0
# Time To Fit: 0.0026441574096679687, Mean Score: 1.0

# %% [markdown]
# ### Bagging & Bootstrapping

# %%
import pandas as pd
df_wine = pd.read_csv('https://archive.ics.uci.edu/ml/'
'machine-learning-databases/'
'wine/wine.data',
header=None)
df_wine.columns = ['Class label', 'Alcohol',
'Malic acid', 'Ash',
'Alcalinity of ash',
'Magnesium', 'Total phenols',
'Flavanoids', 'Nonflavanoid phenols',
'Proanthocyanins',
'Color intensity', 'Hue',
'OD280/OD315 of diluted wines',
'Proline']

# %%
data = df_wine[ df_wine['Class label'] != 1 ]

# %%
y = data['Class label'].values
X = data[ ["Alcohol", "OD280/OD315 of diluted wines"] ].values

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
le = LabelEncoder()

# %%
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size = 0.2, random_state=0, stratify = y)

# %%
from sklearn.ensemble import BaggingClassifier

# %%
tree = DecisionTreeClassifier( criterion="entropy", random_state=0, max_depth=1)
bag = BaggingClassifier( estimator = tree, n_estimators=500, max_features=1, 
                        max_samples=1, bootstrap=True, bootstrap_features=False,
                       random_state = 0)

# %%
from sklearn.metrics import accuracy_score

# %%
tree.fit( X_train, y_train )
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=1, random_state=0)

# %%
y_pred_test = tree.predict( X_test )
y_pred_train = tree.predict( X_train )

# %%
acc_test = accuracy_score( y_true=y_test, y_pred=y_pred_test )
acc_train = accuracy_score( y_true=y_train, y_pred=y_pred_train )

# %%
acc_test
# Out:
# 0.8333333333333334

# %%
'''
    Bagging tecniques can be useful in decreasing the variance of the model.
    However, they cant do anything with the bias. Which means these simple
    structures are not capable of doing such a thing.
'''

# %% [markdown]
# ## Boosting

# %%
'''
    * In contrast to bagging, boosting takes random samples from the training
    dataset without replacement.

    * Also, there is this simple idea about base learner, or let's call them Weak Learners. 
    They perform slightly better than totally random learner.
'''

# %% [markdown]
# ### Manual Imp.

# %%
import numpy as np

# %%
y = np.array( [ 1, -1, 1, 1, 1, -1, -1, 1 ] )

# %%
yhat = np.array( [ 1, 1, 1, 1, 1, 1, -1, -1 ] )

# %%
correct = ( y == yhat )

# %%
weights = np.full( len(y), 0.1 )

# %%
eps = np.mean( ~correct )

# %%
alpha = 0.5 * np.log( ( 1 - eps ) / eps )

# %%
alpha
# Out:
# 0.25541281188299536

# %%
update_if_true = weights[0] * np.exp( -alpha * 1 * 1 )

# %%
update_if_true
# Out:
# 0.07745966692414835

# %%
update_if_wrong = weights[0] * np.exp( alpha * 1 * 1 )

# %%
update_if_wrong
# Out:
# 0.12909944487358058

# %%
weights = np.where( correct == 1, update_if_true, update_if_wrong )

# %%
weights
# Out:
# array([0.07745967, 0.12909944, 0.07745967, 0.07745967, 0.07745967,
#        0.12909944, 0.07745967, 0.12909944])

# %% [markdown]
# ### Sklearn Imp.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
tree = DecisionTreeClassifier( max_depth=1, criterion="entropy", random_state=0 )

# %%
ada = AdaBoostClassifier( n_estimators=500, random_state=0, learning_rate=0.1, estimator=tree )

# %%
tree.fit( X_train, y_train )
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=1, random_state=0)

# %%
y_train_pred = tree.predict( X_train )
y_test_pred = tree.predict( X_test )

# %%
tree_train = accuracy_score( y_true=y_train, y_pred=y_train_pred )
tree_test = accuracy_score( y_true=y_test, y_pred=y_test_pred )

# %%
print(f"Decision Tree train/test: {tree_train:.2f}/{tree_test:.2f} " )
# Out:
# Decision Tree train/test: 0.94/0.83

# %%
ada.fit( X_train, y_train )
# Out:
# /home/ahmed4/ml.py/ml/lib/python3.12/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                     max_depth=1,
#                                                     random_state=0),
#                    learning_rate=0.1, n_estimators=500, random_state=0)

# %%
y_train_pred = ada.predict( X_train )
y_test_pred = ada.predict( X_test )

# %%
ada_test_score = accuracy_score( y_test_pred, y_test )
ada_train_score = accuracy_score( y_train_pred, y_train )

# %%
print(f"Decision Ada train/test: {ada_train_score:.2f}/{ada_test_score:.2f} " )
# Out:
# Decision Ada train/test: 1.00/0.79
